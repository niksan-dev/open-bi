# %%
from openbi.datasource.json_connector import JSONConnector

connector = JSONConnector(

    source="../examples/sales.json",

    dataset_name="Retail Sales"

)

result = connector.load()
print(result.statistics)
dataset = result.dataset
print(dataset)
print(dataset.name)
print(dataset.source)
# Out:
# DataSourceStatistics(execution_time_ms=20.89680000062799, table_count=1, row_count=2, column_count=3)
# Dataset(name='Retail Sales', model=DataModel(tables={'sales': Table(name='sales', dataframe=  OrderId Customer  Amount
# 0   SP101     John     200
# 1   SP102    Alice     250, columns=[Column(id='2a7c680a-479b-489c-b33e-c1c893644643', created_at=datetime.datetime(2026, 7, 5, 22, 42, 27, 540934), modified_at=datetime.datetime(2026, 7, 5, 22, 42, 27, 540938), name='OrderId', datatype='string', metadata=ColumnMetadata(dtype='string', null_count=0, distinct_count=2, is_unique=True, nullable=False, min_value=None, max_value=None, mean=None, sample_values=['SP101', 'SP102'], primary_key_candidate=True, foreign_key_candidate=False), description=''), Column(id='ee918506-c2a7-4962-ac18-71a381d1a466', created_at=datetime.datetime(2026, 7, 5, 22, 42, 27, 540989), modified_at=datetime.datetime(2026, 7, 5, 22, 42, 27, 540989), name='Customer', datatype='string', metadata=ColumnMetadata(dtype='string', null_count=0, distinct_count=2, is_unique=True, nullable=False, min_value=None, max_value=None, mean=None, sample_values=['John', 'Alice'], primary_key_candidate=False, foreign_key_candidate=False), description=''), Column(id='19f1b8b3-120e-4a9a-a17c-2f3a67a74a89', created_at=datetime.datetime(2026, 7, 5, 22, 42, 27, 541029), modified_at=datetime.datetime(2026, 7, 5, 22, 42, 27, 541029), name='Amount', datatype='Int64', metadata=ColumnMetadata(dtype='Int64', null_count=0, distinct_count=2, is_unique=True, nullable=False, min_value=200.0, max_value=250.0, mean=225.0, sample_values=[200, 250], primary_key_candidate=False, foreign_key_candidate=False), description='')], description='')}, relationships=[]), source='')
# Retail Sales
