# %%
from openbi.connector_options.json_options import JSONOptions
from openbi.connector_options.rest_options import RESTOptions
from openbi.datasource.json_connector import JSONConnector
from openbi.datasource.rest_connector import RESTConnector

connector = JSONConnector(

    source="../examples/sales.json",

    dataset_name="Retail Sales",
    options=JSONOptions()
)   

result = connector.load()
print(result.statistics)
dataset = result.dataset
print(dataset)
print(dataset.name)





connector = RESTConnector(

    "https://jsonplaceholder.typicode.com/users",

    options=RESTOptions(

        timeout=60

    )

)

result = connector.load()

dataset = result.dataset
print("Rest Dataset::" , dataset)
# Out:
# DataSourceStatistics(execution_time_ms=29.308900000614813, table_count=1, row_count=2, column_count=3)
# Dataset(name='Retail Sales', model=SemanticModel(tables={'sales': Table(name='sales', dataframe=  OrderId Customer  Amount
# 0   SP101     John     200
# 1   SP102    Alice     250, columns=[Column(id='be9f40f2-b9b6-46d3-a8d7-0880201228d9', created_at=datetime.datetime(2026, 7, 8, 0, 10, 18, 955956), modified_at=datetime.datetime(2026, 7, 8, 0, 10, 18, 955961), name='OrderId', datatype='string', metadata=ColumnMetadata(dtype='string', null_count=0, distinct_count=2, is_unique=True, nullable=False, min_value=None, max_value=None, mean=None, sample_values=['SP101', 'SP102'], primary_key_candidate=True, foreign_key_candidate=False), description=''), Column(id='0a89c157-927e-47db-86f3-67ee831e4e06', created_at=datetime.datetime(2026, 7, 8, 0, 10, 18, 956028), modified_at=datetime.datetime(2026, 7, 8, 0, 10, 18, 956029), name='Customer', datatype='string', metadata=ColumnMetadata(dtype='string', null_count=0, distinct_count=2, is_unique=True, nullable=False, min_value=None, max_value=None, mean=None, sample_values=['John', 'Alice'], primary_key_candidate=False, foreign_key_candidate=False), description=''), Column(id='297ab03e-0564-4264-bdb8-daaee5d9a73f', created_at=datetime.datetime(2026, 7, 8, 0, 10, 18, 956085), modified_at=datetime.datetime(2026, 7, 8, 0, 10, 18, 956086), name='Amount', datatype='Int64', metadata=ColumnMetadata(dtype='Int64', null_count=0, distinct_count=2, is_unique=True, nullable=False, min_value=200.0, max_value=250.0, mean=225.0, sample_values=[200, 250], primary_key_candidate=False, foreign_key_candidate=False), description='')], description='')}, relationships=[], measures={}, hierarchies={}, perspectives={}, roles={}, kpis={}), description='')
# Retail Sales
# Rest Dataset:: Dataset(name='users', model=SemanticModel(tables={'Data': Table(name='Data', dataframe=   id                      name          username                      email  \
# 0   1             Leanne Graham              Bret          Sincere@april.biz
# 1   2              Ervin Howell         Antonette          Shanna@melissa.tv
# 2   3          Clementine Bauch          Samantha         Nathan@yesenia.net
# 3   4          Patricia Lebsack          Karianne  Julianne.OConner@kory.org
# 4   5          Chelsey Dietrich            Kamren   Lucio_Hettinger@annie.ca
# 5   6      Mrs. Dennis Schulist  Leopoldo_Corkery    Karley_Dach@jasper.info
# 6   7           Kurtis Weissnat      Elwyn.Skiles     Telly.Hoeger@billy.biz
# 7   8  Nicholas Runolfsdottir V     Maxime_Nienow       Sherwood@rosamond.me
# 8   9           Glenna Reichert          Delphine    Chaim_McDermott@dana.io
# 9  10        Clementina DuBuque    Moriah.Stanton     Rey.Padberg@karina.biz
#
#                                              address                  phone  \
# 0  {'street': 'Kulas Light', 'suite': 'Apt. 556',...  1-770-736-8031 x56442
# 1  {'street': 'Victor Plains', 'suite': 'Suite 87...    010-692-6593 x09125
# 2  {'street': 'Douglas Extension', 'suite': 'Suit...         1-463-123-4447
# 3  {'street': 'Hoeger Mall', 'suite': 'Apt. 692',...      493-170-9623 x156
# 4  {'street': 'Skiles Walks', 'suite': 'Suite 351...          (254)954-1289
# 5  {'street': 'Norberto Crossing', 'suite': 'Apt....   1-477-935-8478 x6430
# 6  {'street': 'Rex Trail', 'suite': 'Suite 280', ...           210.067.6132
# 7  {'street': 'Ellsworth Summit', 'suite': 'Suite...      586.493.6943 x140
# 8  {'street': 'Dayna Park', 'suite': 'Suite 449',...   (775)976-6794 x41206
# 9  {'street': 'Kattie Turnpike', 'suite': 'Suite ...           024-648-3804
#
#          website                                            company
# 0  hildegard.org  {'name': 'Romaguera-Crona', 'catchPhrase': 'Mu...
# 1  anastasia.net  {'name': 'Deckow-Crist', 'catchPhrase': 'Proac...
# 2    ramiro.info  {'name': 'Romaguera-Jacobson', 'catchPhrase': ...
# 3       kale.biz  {'name': 'Robel-Corkery', 'catchPhrase': 'Mult...
# 4   demarco.info  {'name': 'Keebler LLC', 'catchPhrase': 'User-c...
# 5        ola.org  {'name': 'Considine-Lockman', 'catchPhrase': '...
# 6       elvis.io  {'name': 'Johns Group', 'catchPhrase': 'Config...
# 7   jacynthe.com  {'name': 'Abernathy Group', 'catchPhrase': 'Im...
# 8     conrad.com  {'name': 'Yost and Sons', 'catchPhrase': 'Swit...
# 9    ambrose.net  {'name': 'Hoeger LLC', 'catchPhrase': 'Central...  , columns=[Column(id='f4f4b8d0-be1a-4bf1-b5a2-2e46b2f4e6c8', created_at=datetime.datetime(2026, 7, 8, 0, 10, 19, 774957), modified_at=datetime.datetime(2026, 7, 8, 0, 10, 19, 774959), name='id', datatype='Int64', metadata=ColumnMetadata(dtype='Int64', null_count=0, distinct_count=10, is_unique=True, nullable=False, min_value=1.0, max_value=10.0, mean=5.5, sample_values=[1, 2, 3, 4, 5], primary_key_candidate=True, foreign_key_candidate=False), description=''), Column(id='18798e33-db41-48c1-a6fe-368d0c9300b5', created_at=datetime.datetime(2026, 7, 8, 0, 10, 19, 775001), modified_at=datetime.datetime(2026, 7, 8, 0, 10, 19, 775001), name='name', datatype='string', metadata=ColumnMetadata(dtype='string', null_count=0, distinct_count=10, is_unique=True, nullable=False, min_value=None, max_value=None, mean=None, sample_values=['Leanne Graham', 'Ervin Howell', 'Clementine Bauch', 'Patricia Lebsack', 'Chelsey Dietrich'], primary_key_candidate=False, foreign_key_candidate=False), description=''), Column(id='9d5bcd58-fdf0-4add-a82e-88dbcf28aaab', created_at=datetime.datetime(2026, 7, 8, 0, 10, 19, 775037), modified_at=datetime.datetime(2026, 7, 8, 0, 10, 19, 775038), name='username', datatype='string', metadata=ColumnMetadata(dtype='string', null_count=0, distinct_count=10, is_unique=True, nullable=False, min_value=None, max_value=None, mean=None, sample_values=['Bret', 'Antonette', 'Samantha', 'Karianne', 'Kamren'], primary_key_candidate=False, foreign_key_candidate=False), description=''), Column(id='9f88ff8b-edd1-4a6a-af10-865e2dc47090', created_at=datetime.datetime(2026, 7, 8, 0, 10, 19, 775072), modified_at=datetime.datetime(2026, 7, 8, 0, 10, 19, 775073), name='email', datatype='string', metadata=ColumnMetadata(dtype='string', null_count=0, distinct_count=10, is_unique=True, nullable=False, min_value=None, max_value=None, mean=None, sample_values=['Sincere@april.biz', 'Shanna@melissa.tv', 'Nathan@yesenia.net', 'Julianne.OConner@kory.org', 'Lucio_Hettinger@annie.ca'], primary_key_candidate=False, foreign_key_candidate=False), description=''), Column(id='d874534e-d01e-480e-b73a-c1136c8cb0e0', created_at=datetime.datetime(2026, 7, 8, 0, 10, 19, 775109), modified_at=datetime.datetime(2026, 7, 8, 0, 10, 19, 775110), name='address', datatype='string', metadata=ColumnMetadata(dtype='string', null_count=0, distinct_count=10, is_unique=True, nullable=False, min_value=None, max_value=None, mean=None, sample_values=["{'street': 'Kulas Light', 'suite': 'Apt. 556', 'city': 'Gwenborough', 'zipcode': '92998-3874', 'geo': {'lat': '-37.3159', 'lng': '81.1496'}}", "{'street': 'Victor Plains', 'suite': 'Suite 879', 'city': 'Wisokyburgh', 'zipcode': '90566-7771', 'geo': {'lat': '-43.9509', 'lng': '-34.4618'}}", "{'street': 'Douglas Extension', 'suite': 'Suite 847', 'city': 'McKenziehaven', 'zipcode': '59590-4157', 'geo': {'lat': '-68.6102', 'lng': '-47.0653'}}", "{'street': 'Hoeger Mall', 'suite': 'Apt. 692', 'city': 'South Elvis', 'zipcode': '53919-4257', 'geo': {'lat': '29.4572', 'lng': '-164.2990'}}", "{'street': 'Skiles Walks', 'suite': 'Suite 351', 'city': 'Roscoeview', 'zipcode': '33263', 'geo': {'lat': '-31.8129', 'lng': '62.5342'}}"], primary_key_candidate=False, foreign_key_candidate=False), description=''), Column(id='133d5555-fa65-402b-bddd-cfa97bf89ca6', created_at=datetime.datetime(2026, 7, 8, 0, 10, 19, 775145), modified_at=datetime.datetime(2026, 7, 8, 0, 10, 19, 775146), name='phone', datatype='string', metadata=ColumnMetadata(dtype='string', null_count=0, distinct_count=10, is_unique=True, nullable=False, min_value=None, max_value=None, mean=None, sample_values=['1-770-736-8031 x56442', '010-692-6593 x09125', '1-463-123-4447', '493-170-9623 x156', '(254)954-1289'], primary_key_candidate=False, foreign_key_candidate=False), description=''), Column(id='a3fa59af-8fd7-4cc7-acdf-c79d25ea65cb', created_at=datetime.datetime(2026, 7, 8, 0, 10, 19, 775179), modified_at=dateti ...
